# %% [markdown]
# # Acesso aos dados

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/leonhgomes/Pandas/main/pokemon_data.csv')

#Acessando o nome das colunas e o inicio e fim da tabela
print ( df.columns )
print(df.head(3))
print (df.tail(2))
# Out:
# Index(['#', 'Nome', 'Tipo 1', 'Tipo 2', 'Vida', 'Ataque', 'Defensa', 'Atq Esp',
#        'Def Esp', 'Velocidade', 'Geracao', 'Lendario'],
#       dtype='object')
#    #       Nome  Tipo 1    Tipo 2  ...  Def Esp  Velocidade  Geracao  Lendario
# 0  1  Bulbasaur  Planta  Venenoso  ...       65          45        1     False
# 1  2    Ivysaur  Planta  Venenoso  ...       80          60        1     False
# 2  3   Venusaur  Planta  Venenoso  ...      100          80        1     False
#
# [3 rows x 12 columns]
#        #                Nome    Tipo 1  ... Velocidade  Geracao  Lendario
# 798  720  HoopaHoopa Unbound  Psiquico  ...         80        6      True
# 799  721           Volcanion      Fogo  ...         70        6      True
#
# [2 rows x 12 columns]

# %%
#Acessar colunas individuais
#df['Nome']
df[['Nome','Tipo 1']][0:150:2]
# Out:
#                           Nome    Tipo 1
# 0                    Bulbasaur    Planta
# 2                     Venusaur    Planta
# 4                   Charmander      Fogo
# 6                    Charizard      Fogo
# 8    CharizardMega Charizard Y      Fogo
# ..                         ...       ...
# 140                   Gyarados      Agua
# 142                     Lapras      Agua
# 144                      Eevee    Normal
# 146                    Jolteon  Electric
# 148                    Porygon    Normal
#
# [75 rows x 2 columns]

# %%
#acessando linhas individuais
df.iloc[:4]
# Out:
#    #                   Nome  Tipo 1  ... Velocidade  Geracao  Lendario
# 0  1              Bulbasaur  Planta  ...         45        1     False
# 1  2                Ivysaur  Planta  ...         60        1     False
# 2  3               Venusaur  Planta  ...         80        1     False
# 3  3  VenusaurMega Venusaur  Planta  ...         80        1     False
#
# [4 rows x 12 columns]

# %%
#acessando linhas e colunas individuais
df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
#busca por nome
df.loc[df['Tipo 1'] == 'Fogo' ]

# %%
#acessar linhas por nome

for indice, linha in df.iterrows() :
  print(indice,linha['Nome'])
  if linha['#'] == 150 :
    break

# %%
#valores estatísticos básicos
df.describe()
# Out:
#                 #        Vida      Ataque  ...     Def Esp  Velocidade    Geracao
# count  800.000000  800.000000  800.000000  ...  800.000000  800.000000  800.00000
# mean   362.813750   69.258750   79.001250  ...   71.902500   68.277500    3.32375
# std    208.343798   25.534669   32.457366  ...   27.828916   29.060474    1.66129
# min      1.000000    1.000000    5.000000  ...   20.000000    5.000000    1.00000
# 25%    184.750000   50.000000   55.000000  ...   50.000000   45.000000    2.00000
# 50%    364.500000   65.000000   75.000000  ...   70.000000   65.000000    3.00000
# 75%    539.250000   80.000000  100.000000  ...   90.000000   90.000000    5.00000
# max    721.000000  255.000000  190.000000  ...  230.000000  180.000000    6.00000
#
# [8 rows x 8 columns]

# %% [markdown]
# # Ordenação

# %%
#ordem alfabética inversa
df.sort_values('Nome',ascending=False)
# Out:
#        #                     Nome    Tipo 1  ... Velocidade  Geracao  Lendario
# 794  718         Zygarde50% Forme    Dragao  ...         95        6      True
# 695  634                 Zweilous   Noturno  ...         58        5     False
# 46    41                    Zubat  Venenoso  ...         55        1     False
# 631  570                    Zorua   Noturno  ...         65        5     False
# 632  571                  Zoroark   Noturno  ...        105        5     False
# ..   ...                      ...       ...  ...        ...      ...       ...
# 393  359          AbsolMega Absol   Noturno  ...        115        3     False
# 392  359                    Absol   Noturno  ...         75        3     False
# 68    63                     Abra  Psiquico  ...         90        1     False
# 511  460  AbomasnowMega Abomasnow    Planta  ...         30        4     False
# 510  460                Abomasnow    Planta  ...         60        4     False
#
# [800 rows x 12 columns]

# %% [markdown]
# # Realizando Mudanças nos dados

# %%
df['Total'] = df['Ataque'] + df['Atq Esp'] + df['Def Esp'] + df['Defensa'] +df['Velocidade'] + df['Vida']
df
# Out:
#        #                   Nome    Tipo 1  ... Geracao  Lendario  Total
# 0      1              Bulbasaur    Planta  ...       1     False    318
# 1      2                Ivysaur    Planta  ...       1     False    405
# 2      3               Venusaur    Planta  ...       1     False    525
# 3      3  VenusaurMega Venusaur    Planta  ...       1     False    625
# 4      4             Charmander      Fogo  ...       1     False    309
# ..   ...                    ...       ...  ...     ...       ...    ...
# 795  719                Diancie     Pedra  ...       6      True    600
# 796  719    DiancieMega Diancie     Pedra  ...       6      True    700
# 797  720    HoopaHoopa Confined  Psiquico  ...       6      True    600
# 798  720     HoopaHoopa Unbound  Psiquico  ...       6      True    680
# 799  721              Volcanion      Fogo  ...       6      True    600
#
# [800 rows x 13 columns]

# %%
df = df.drop(columns=['Total'])
df
# Out:
#        #                   Nome    Tipo 1  ... Velocidade  Geracao  Lendario
# 0      1              Bulbasaur    Planta  ...         45        1     False
# 1      2                Ivysaur    Planta  ...         60        1     False
# 2      3               Venusaur    Planta  ...         80        1     False
# 3      3  VenusaurMega Venusaur    Planta  ...         80        1     False
# 4      4             Charmander      Fogo  ...         65        1     False
# ..   ...                    ...       ...  ...        ...      ...       ...
# 795  719                Diancie     Pedra  ...         50        6      True
# 796  719    DiancieMega Diancie     Pedra  ...        110        6      True
# 797  720    HoopaHoopa Confined  Psiquico  ...         70        6      True
# 798  720     HoopaHoopa Unbound  Psiquico  ...         80        6      True
# 799  721              Volcanion      Fogo  ...         70        6      True
#
# [800 rows x 12 columns]

# %%
#forma alternativa de criar coluna Total
df['Total'] = df.iloc[:,4:10].sum(axis=1)
df
# Out:
#        #                   Nome    Tipo 1  ... Geracao  Lendario  Total
# 0      1              Bulbasaur    Planta  ...       1     False    318
# 1      2                Ivysaur    Planta  ...       1     False    405
# 2      3               Venusaur    Planta  ...       1     False    525
# 3      3  VenusaurMega Venusaur    Planta  ...       1     False    625
# 4      4             Charmander      Fogo  ...       1     False    309
# ..   ...                    ...       ...  ...     ...       ...    ...
# 795  719                Diancie     Pedra  ...       6      True    600
# 796  719    DiancieMega Diancie     Pedra  ...       6      True    700
# 797  720    HoopaHoopa Confined  Psiquico  ...       6      True    600
# 798  720     HoopaHoopa Unbound  Psiquico  ...       6      True    680
# 799  721              Volcanion      Fogo  ...       6      True    600
#
# [800 rows x 13 columns]

# %%
#renomeando
df.rename({'Defensa':'Defesa'},axis=1,inplace=True)
df
# Out:
#        #                   Nome    Tipo 1  ... Geracao  Lendario  Total
# 0      1              Bulbasaur    Planta  ...       1     False    318
# 1      2                Ivysaur    Planta  ...       1     False    405
# 2      3               Venusaur    Planta  ...       1     False    525
# 3      3  VenusaurMega Venusaur    Planta  ...       1     False    625
# 4      4             Charmander      Fogo  ...       1     False    309
# ..   ...                    ...       ...  ...     ...       ...    ...
# 795  719                Diancie     Pedra  ...       6      True    600
# 796  719    DiancieMega Diancie     Pedra  ...       6      True    700
# 797  720    HoopaHoopa Confined  Psiquico  ...       6      True    600
# 798  720     HoopaHoopa Unbound  Psiquico  ...       6      True    680
# 799  721              Volcanion      Fogo  ...       6      True    600
#
# [800 rows x 13 columns]

# %%
#reordenar colunas

#df = df[ ['Total','Vida','Defesa']    ]

cols = list(df.columns.values )
df = df [cols[0:4] + [cols[-1]] + cols[4:12]]
df
# Out:
#        #                   Nome    Tipo 1  ... Velocidade  Geracao  Lendario
# 0      1              Bulbasaur    Planta  ...         45        1     False
# 1      2                Ivysaur    Planta  ...         60        1     False
# 2      3               Venusaur    Planta  ...         80        1     False
# 3      3  VenusaurMega Venusaur    Planta  ...         80        1     False
# 4      4             Charmander      Fogo  ...         65        1     False
# ..   ...                    ...       ...  ...        ...      ...       ...
# 795  719                Diancie     Pedra  ...         50        6      True
# 796  719    DiancieMega Diancie     Pedra  ...        110        6      True
# 797  720    HoopaHoopa Confined  Psiquico  ...         70        6      True
# 798  720     HoopaHoopa Unbound  Psiquico  ...         80        6      True
# 799  721              Volcanion      Fogo  ...         70        6      True
#
# [800 rows x 13 columns]

# %% [markdown]
# #Salvar Arquivos

# %%
#df.to_csv('modificado.csv')
df.to_csv('modificado.csv',index=False)

#df.to_csv('modificado.txt',index=False,sep='\t')

#df.to_excel('modificado.xlsx',index=False)

# %% [markdown]
# #Filtrando dados

# %%
#fogo E agua
novo_df = df.loc[(df['Tipo 1'] =='Fogo') & (df['Tipo 2'] == 'Agua') ]
novo_df
# Out:
#        #       Nome Tipo 1 Tipo 2  ...  Def Esp  Velocidade  Geracao  Lendario
# 799  721  Volcanion   Fogo   Agua  ...       90          70        6      True
#
# [1 rows x 13 columns]

# %%
#fogo OU agua
novo_df = df.loc[(df['Tipo 1'] =='Fogo') | (df['Tipo 1'] == 'Agua') ]
novo_df.reset_index(drop=True,inplace=True)
novo_df
# Out:
#        #                       Nome Tipo 1  ... Velocidade  Geracao  Lendario
# 0      4                 Charmander   Fogo  ...         65        1     False
# 1      5                 Charmeleon   Fogo  ...         80        1     False
# 2      6                  Charizard   Fogo  ...        100        1     False
# 3      6  CharizardMega Charizard X   Fogo  ...        100        1     False
# 4      6  CharizardMega Charizard Y   Fogo  ...        100        1     False
# ..   ...                        ...    ...  ...        ...      ...       ...
# 159  667                     Litleo   Fogo  ...         72        6     False
# 160  668                     Pyroar   Fogo  ...        106        6     False
# 161  692                  Clauncher   Agua  ...         44        6     False
# 162  693                  Clawitzer   Agua  ...         59        6     False
# 163  721                  Volcanion   Fogo  ...         70        6      True
#
# [164 rows x 13 columns]

# %%
#filtrando versões Mega
novo_df = df.loc[~df['Nome'].str.contains('Mega ')]
novo_df
# Out:
#        #                 Nome    Tipo 1  ... Velocidade  Geracao  Lendario
# 0      1            Bulbasaur    Planta  ...         45        1     False
# 1      2              Ivysaur    Planta  ...         60        1     False
# 2      3             Venusaur    Planta  ...         80        1     False
# 4      4           Charmander      Fogo  ...         65        1     False
# 5      5           Charmeleon      Fogo  ...         80        1     False
# ..   ...                  ...       ...  ...        ...      ...       ...
# 794  718     Zygarde50% Forme    Dragao  ...         95        6      True
# 795  719              Diancie     Pedra  ...         50        6      True
# 797  720  HoopaHoopa Confined  Psiquico  ...         70        6      True
# 798  720   HoopaHoopa Unbound  Psiquico  ...         80        6      True
# 799  721            Volcanion      Fogo  ...         70        6      True
#
# [752 rows x 13 columns]

# %%
#expressão para pokemons de agua ou fogo
import re

novo_df = df.loc[df['Tipo 1'].str.contains('fogo|agua',flags=re.I,regex=True)]
novo_df
# Out:
#        #                       Nome Tipo 1  ... Velocidade  Geracao  Lendario
# 4      4                 Charmander   Fogo  ...         65        1     False
# 5      5                 Charmeleon   Fogo  ...         80        1     False
# 6      6                  Charizard   Fogo  ...        100        1     False
# 7      6  CharizardMega Charizard X   Fogo  ...        100        1     False
# 8      6  CharizardMega Charizard Y   Fogo  ...        100        1     False
# ..   ...                        ...    ...  ...        ...      ...       ...
# 735  667                     Litleo   Fogo  ...         72        6     False
# 736  668                     Pyroar   Fogo  ...        106        6     False
# 762  692                  Clauncher   Agua  ...         44        6     False
# 763  693                  Clawitzer   Agua  ...         59        6     False
# 799  721                  Volcanion   Fogo  ...         70        6      True
#
# [164 rows x 13 columns]

# %%
#filtrando pokemons que comecem com PI
novo_df = df.loc[df['Nome'].str.contains('^pi',flags=re.I,regex=True)]
novo_df
# Out:
#        #     Nome    Tipo 1  Tipo 2  ...  Def Esp  Velocidade  Geracao  Lendario
# 189  175   Togepi      Fada     NaN  ...       65          20        2     False
# 501  451  Skorupi  Venenoso  Inseto  ...       55          65        4     False
#
# [2 rows x 13 columns]

# %% [markdown]
# #Mudanças condicionais

# %%
df.loc[df['Tipo 1'] == 'Fogo', 'Tipo 1'] = 'Fogueteiro'
df
# Out:
#        #                   Nome      Tipo 1  ... Velocidade  Geracao  Lendario
# 0      1              Bulbasaur      Planta  ...         45        1     False
# 1      2                Ivysaur      Planta  ...         60        1     False
# 2      3               Venusaur      Planta  ...         80        1     False
# 3      3  VenusaurMega Venusaur      Planta  ...         80        1     False
# 4      4             Charmander  Fogueteiro  ...         65        1     False
# ..   ...                    ...         ...  ...        ...      ...       ...
# 795  719                Diancie       Pedra  ...         50        6      True
# 796  719    DiancieMega Diancie       Pedra  ...        110        6      True
# 797  720    HoopaHoopa Confined    Psiquico  ...         70        6      True
# 798  720     HoopaHoopa Unbound    Psiquico  ...         80        6      True
# 799  721              Volcanion  Fogueteiro  ...         70        6      True
#
# [800 rows x 13 columns]

# %%
df.loc[df['Total'] >500, 'Lendario'] = True
df
# Out:
#        #                   Nome      Tipo 1  ... Velocidade  Geracao  Lendario
# 0      1              Bulbasaur      Planta  ...         45        1     False
# 1      2                Ivysaur      Planta  ...         60        1     False
# 2      3               Venusaur      Planta  ...         80        1      True
# 3      3  VenusaurMega Venusaur      Planta  ...         80        1      True
# 4      4             Charmander  Fogueteiro  ...         65        1     False
# ..   ...                    ...         ...  ...        ...      ...       ...
# 795  719                Diancie       Pedra  ...         50        6      True
# 796  719    DiancieMega Diancie       Pedra  ...        110        6      True
# 797  720    HoopaHoopa Confined    Psiquico  ...         70        6      True
# 798  720     HoopaHoopa Unbound    Psiquico  ...         80        6      True
# 799  721              Volcanion  Fogueteiro  ...         70        6      True
#
# [800 rows x 13 columns]

# %%
df.loc[df['Velocidade'] > 70, ['Lendario','Geracao']] = ['Teste1','Teste2']
df
# Out:
#        #                   Nome      Tipo 1  ... Velocidade  Geracao  Lendario
# 0      1              Bulbasaur      Planta  ...         45        1     False
# 1      2                Ivysaur      Planta  ...         60        1     False
# 2      3               Venusaur      Planta  ...         80   Teste2    Teste1
# 3      3  VenusaurMega Venusaur      Planta  ...         80   Teste2    Teste1
# 4      4             Charmander  Fogueteiro  ...         65        1     False
# ..   ...                    ...         ...  ...        ...      ...       ...
# 795  719                Diancie       Pedra  ...         50        6      True
# 796  719    DiancieMega Diancie       Pedra  ...        110   Teste2    Teste1
# 797  720    HoopaHoopa Confined    Psiquico  ...         70        6      True
# 798  720     HoopaHoopa Unbound    Psiquico  ...         80   Teste2    Teste1
# 799  721              Volcanion  Fogueteiro  ...         70        6      True
#
# [800 rows x 13 columns]

# %% [markdown]
# #Estatisticas agrupadas (Groupby)

# %%
df = pd.read_csv('modificado.csv')
df
# Out:
#        #                   Nome    Tipo 1  ... Velocidade  Geracao  Lendario
# 0      1              Bulbasaur    Planta  ...         45        1     False
# 1      2                Ivysaur    Planta  ...         60        1     False
# 2      3               Venusaur    Planta  ...         80        1     False
# 3      3  VenusaurMega Venusaur    Planta  ...         80        1     False
# 4      4             Charmander      Fogo  ...         65        1     False
# ..   ...                    ...       ...  ...        ...      ...       ...
# 795  719                Diancie     Pedra  ...         50        6      True
# 796  719    DiancieMega Diancie     Pedra  ...        110        6      True
# 797  720    HoopaHoopa Confined  Psiquico  ...         70        6      True
# 798  720     HoopaHoopa Unbound  Psiquico  ...         80        6      True
# 799  721              Volcanion      Fogo  ...         70        6      True
#
# [800 rows x 13 columns]

# %%
df.groupby(['Tipo 1']).mean().sort_values('Ataque',ascending=False)
# Out:
#                    #       Total       Vida  ...  Velocidade   Geracao  Lendario
# Tipo 1                                       ...
# Dragao    474.375000  550.531250  83.312500  ...   83.031250  3.875000  0.375000
# Lutador   363.851852  416.444444  69.851852  ...   66.074074  3.370370  0.000000
# Terra     356.281250  437.500000  73.781250  ...   63.906250  3.156250  0.125000
# Pedra     392.727273  453.750000  65.363636  ...   55.909091  3.454545  0.090909
# Metalico  442.851852  487.703704  65.222222  ...   55.259259  3.851852  0.148148
# Noturno   461.354839  445.741935  66.806452  ...   76.161290  4.032258  0.064516
# Fogo      327.403846  458.076923  69.903846  ...   74.442308  3.211538  0.096154
# Voador    677.750000  485.000000  70.750000  ...  102.500000  5.500000  0.500000
# Venenoso  251.785714  399.142857  67.250000  ...   63.571429  2.535714  0.000000
# Agua      303.089286  430.455357  72.062500  ...   65.964286  2.857143  0.035714
# Fantasma  486.500000  439.562500  64.437500  ...   64.343750  4.187500  0.062500
# Normal    319.173469  401.683673  77.275510  ...   71.551020  3.051020  0.020408
# Planta    344.871429  421.142857  67.271429  ...   61.928571  3.357143  0.042857
# Gelo      423.541667  433.458333  72.000000  ...   63.458333  3.541667  0.083333
# Psiquico  380.807018  475.947368  70.631579  ...   81.491228  3.385965  0.245614
# Inseto    334.492754  378.927536  56.884058  ...   61.681159  3.217391  0.000000
# Electric  363.500000  443.409091  59.795455  ...   84.500000  3.272727  0.090909
# Fada      449.529412  413.176471  74.117647  ...   48.588235  4.117647  0.058824
#
# [18 rows x 10 columns]

# %%
df['contador']=1

df.groupby(['Tipo 1','Tipo 2']).count()['contador']
# Out:
# Tipo 1    Tipo 2
# Agua      Dragao      2
#           Electric    2
#           Fada        2
#           Fantasma    2
#           Gelo        3
#                      ..
# Venenoso  Lutador     2
#           Noturno     3
#           Terra       2
#           Voador      3
# Voador    Dragao      2
# Name: contador, Length: 136, dtype: int64

# %% [markdown]
# #Blocos de memória

# %%
#carregar linhas de 5 em 5
for df in pd.read_csv('modificado.csv',chunksize=5) :
  print(df)

# %% [markdown]
# # Plotagem de dados

# %%
#histograma

import matplotlib.pyplot as plt


atributo='Defesa'

bins = range(0,201,20)
plt.xticks(bins)

df = pd.read_csv('modificado.csv')

plt.title('Distribuição dos pokemons por ' + atributo)
plt.xlabel('Valor do atributo ' + atributo)
plt.ylabel('Quantidade de pokemons')
plt.hist(df[atributo],bins=bins)
plt.show()

# %%
#barra vertical

atributo='Defesa'
tipos = df.groupby('Tipo 1').mean().sort_values(atributo,ascending=False)
linha = tipos.index.tolist()
coluna = tipos[atributo].tolist()
figura = plt.figure(figsize=(14,4)).add_axes([0,0,1,1])
figura.bar(linha,coluna)


plt.xlabel('Tipos de pokemons')
plt.ylabel('Valor médio do atributo ' +atributo)
plt.title('Valor médio do atributo ' + atributo + 'por tipo de pokemons')


for i,v in enumerate(coluna) :
  plt.annotate( f"{v:.2f}",(i-0.3,v+1) )



plt.show()

# %% [markdown]
# # Exemplo

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/leonhgomes/Pandas/main/pokemon_data.csv')

df.sample(n=6)[ ['Nome','Ataque']  ]
# Out:
#            Nome  Ataque
# 630    Garbodor      95
# 776      Goodra     100
# 447  Kricketune      85
# 91        Doduo      85
# 26      Spearow      60
# 65      Poliwag      50
